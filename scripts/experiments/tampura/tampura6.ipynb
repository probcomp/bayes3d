# %%
import numpy as np
import jax.numpy as jnp
import jax
import bayes3d as b
import time
from PIL import Image
from scipy.spatial.transform import Rotation as R
import matplotlib.pyplot as plt
import cv2
import trimesh
import os
import glob
import bayes3d.neural
import pickle
# Can be helpful for debugging:
# jax.config.update('jax_enable_checks', True) 
from bayes3d.neural.segmentation import carvekit_get_foreground_mask
import genjax

# %%
b.setup_visualizer()
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7000/static/

# %%
with open("problems/img1.pickle", "rb") as file:
    img = pickle.load(file)

K = img['camera_matrix']
fx, fy, cx, cy = K[0,0],K[1,1],K[0,2],K[1,2]
h,w = img["depthPixels"].shape
intrinsics = b.Intrinsics(h,w,fx,fy,cx,cy,0.001,10000.0)

rgbd = b.RGBD(
    img["rgbPixels"],
    img["depthPixels"],
    b.t3d.pybullet_pose_to_transform(img["camera_pose"]),
    intrinsics
)

# %%
b.get_rgb_image(rgbd.rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=320x240>

# %%
b.get_depth_image(rgbd.depth)
# Out:
# <PIL.Image.Image image mode=RGB size=320x240>

# %%
import pyransac3d
def find_plane(point_cloud, threshold,  minPoints=100, maxIteration=1000):
    """
    Returns the pose of a plane from a point cloud.
    """
    plane = pyransac3d.Plane()
    plane_eq, inliers = plane.fit(point_cloud, threshold, minPoints=minPoints, maxIteration=maxIteration)
    plane_pose = b.utils.plane_eq_to_plane_pose(plane_eq)
    return plane_pose, inliers

# %%
scaling_factor = 0.5
rgbd_scaled_down = b.RGBD.scale_rgbd(rgbd, scaling_factor)

cloud = b.unproject_depth(rgbd_scaled_down.depth, rgbd_scaled_down.intrinsics).reshape(-1,3)
too_big_indices = np.where(cloud[:,2] > 3.0)
cloud = cloud.at[too_big_indices, :].set(np.nan)

too_small_indices = np.where(cloud[:,2] < 0.1)
cloud = cloud.at[too_small_indices, :].set(np.nan)

table_pose, inliers = find_plane(np.array(cloud), 0.01)

# %%
face_child = 3

camera_pose = jnp.eye(4)
table_pose_in_cam_frame = b.t3d.inverse_pose(camera_pose) @ table_pose
if table_pose_in_cam_frame[2,2] > 0:
    table_pose = table_pose @ b.t3d.transform_from_axis_angle(jnp.array([1.0, 0.0, 0.0]), jnp.pi)

b.clear()
b.show_cloud("1", cloud)
b.show_pose("table", table_pose)

# %%
obs_img = b.unproject_depth_jit(rgbd_scaled_down.depth, rgbd_scaled_down.intrinsics)

# set inliers to zero
x_indices, y_indices = np.unravel_index(inliers, obs_img.shape[:2])
obs_img2 = obs_img.at[x_indices, y_indices, :].set(0.)#jnp.array([100.0,100.0,100.0]))

x_indices, y_indices = np.unravel_index(too_big_indices, obs_img.shape[:2])
obs_img3 = obs_img2.at[x_indices, y_indices, :].set(0.)

x_indices, y_indices = np.unravel_index(too_small_indices, obs_img.shape[:2])
obs_img3 = obs_img3.at[x_indices, y_indices, :].set(0.)

b.clear()
b.show_cloud("Obs without table or too-far points", obs_img3.reshape(-1,3))

# %%
# Add every ply file from the model dir using b.RENDERER.add_mesh_from_file(mesh_path)
b.setup_renderer(rgbd_scaled_down.intrinsics)
model_dir = os.path.join(b.utils.get_assets_dir(),"bop/ycbv/models")
for model_path in glob.glob(os.path.join(model_dir, "*.ply")):
    b.RENDERER.add_mesh_from_file(model_path, scaling_factor=1.0/1000.0)
# Out:
# [E rasterize_gl.cpp:121] OpenGL version reported as 4.6
# Increasing frame buffer size to (width, height, depth) = (160, 128, 1024)

# %%
b.RENDERER.far
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/georgematheos/bayes3d/scripts/experiments/tampura/tampura5.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B34.148.112.108/home/georgematheos/bayes3d/scripts/experiments/tampura/tampura5.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> b.RENDERER.far
#
# AttributeError: 'Renderer' object has no attribute 'far'

# %%
width = 0.03
ang = jnp.pi
num_position_grids = 51
num_angle_grids = 51
contact_param_deltas = b.utils.make_translation_grid_enumeration_3d(
    -width, -width, -ang,
    width, width, ang,
    num_position_grids,num_position_grids,num_angle_grids
)

grid_params = [
    (2.0, jnp.pi, (15, 15, 15)),
      (0.5, jnp.pi, (15, 15, 15)), (0.4, jnp.pi, (15, 15, 15)),
    (0.05, jnp.pi/3, (15,15,15)),
    (0.02, jnp.pi, (9,9,51))
    , (0.01, jnp.pi/5, (15,15,15)),
      (0.01, 0.0, (31,31,1)),(0.05, 0.0, (31,31,1))
]
contact_param_gridding_schedule = [
    b.utils.make_translation_grid_enumeration_3d(
        -x, -x, -ang,
        x, x, ang,
        *nums
    )
    for (x,ang,nums) in grid_params
]

_cp_to_pose = lambda cp, index: table_pose @ b.scene_graph.relative_pose_from_edge(cp, face_child, b.RENDERER.model_box_dims[index])
cps_to_pose= jax.vmap(_cp_to_pose, in_axes=(0,0,))
cps_to_pose_jit = jax.jit(cps_to_pose)
cps_to_pose_parallel = jax.vmap(cps_to_pose, in_axes=(0,None,))
cps_to_pose_parallel_jit = jax.jit(cps_to_pose_parallel)

key = jax.random.PRNGKey(30)

def score_images(rendered, observed):
    return -jnp.linalg.norm(observed - rendered, axis=-1).mean()

def score_images(rendered, observed):
    return -jnp.linalg.norm(observed - rendered, axis=-1).mean()

def score_images(rendered, observed):
    distances = jnp.linalg.norm(observed - rendered, axis=-1)
    width = 0.02
    probabilities_per_pixel = (distances < width/2) / width
    return probabilities_per_pixel.mean()

score_vmap = jax.jit(jax.vmap(score_images, in_axes=(0, None)))

def grid_and_max(key, cps, indices, number, grid, obs_img):
    cps_expanded = jnp.repeat(cps[None,...], grid.shape[0], axis=0)
    cps_expanded = cps_expanded.at[:,number,:].set(cps_expanded[:,number,:] + grid)
    cp_poses = cps_to_pose_parallel(cps_expanded, indices)
    rendered_images = b.RENDERER.render_many(cp_poses, indices)[...,:3]
    scores = score_vmap(rendered_images, obs_img)
    # top 5 scores:
    best_idx = jnp.argmax(scores) # jnp.argsort(scores)[-4]
    next_best_indices = jnp.argsort(scores)[-5:-1]
    cps = cps_expanded[best_idx]
    return cps, scores[best_idx], scores[next_best_indices]

def grid_and_sample(key, cps, indices, number, grid, obs_img):
    cps_expanded = jnp.repeat(cps[None,...], grid.shape[0], axis=0)
    cps_expanded = cps_expanded.at[:,number,:].set(cps_expanded[:,number,:] + grid)
    cp_poses = cps_to_pose_parallel(cps_expanded, indices)
    rendered_images = b.RENDERER.render_many(cp_poses, indices)[...,:3]
    scores = score_vmap(rendered_images, obs_img)

    norm_log_scores = scores - jax.scipy.special.logsumexp(scores)
    norm_scores = jnp.exp(norm_log_scores)
    idx = jax.random.categorical(key, norm_scores)
    cps = cps_expanded[idx]
    return cps, scores[idx], jnp.argmax(scores)

def c2f(key, potential_cps, potential_indices, number, contact_param_gridding_schedule, obs_img):
    for cp_grid in contact_param_gridding_schedule:
        potential_cps, score, score2 = grid_and_max(key, potential_cps, potential_indices, number, cp_grid, obs_img)
    return potential_cps, score, score2
c2f_jit = jax.jit(c2f)

# %%
cps = jnp.zeros((0,3))
indices = jnp.array([], dtype=jnp.int32)
obs_img = obs_img3 # b.unproject_depth_jit(rgbd_scaled_down.depth, rgbd_scaled_down.intrinsics)

# %%
cps = jnp.zeros((0,3))
indices = jnp.array([], dtype=jnp.int32)
obs_img = obs_img3

# %%
best_score = 0.0
best_index = -1
best_cps = None
best_indices = None
key = jax.random.split(key,2)[0]
low, high = jnp.array([-0.4, -0.4, -jnp.pi]), jnp.array([0.4, 0.4, jnp.pi])

for next_index in range(len(b.RENDERER.model_box_dims)):
    potential_indices = jnp.concatenate([indices, jnp.array([next_index])])
    potential_cps = jnp.concatenate([cps, jax.random.uniform(key, shape=(1,3,),minval=low, maxval=high)])
    potential_cps, score, _ = c2f_jit(key, potential_cps, potential_indices, len(potential_indices) - 1, contact_param_gridding_schedule, obs_img)
    print(score)
    if score > best_score:
        best_index = next_index
        best_score = score
        best_cps = potential_cps
        best_indices = potential_indices
cps = best_cps
indices = best_indices

b.clear()
b.show_cloud("obs", obs_img.reshape(-1,3))
b.show_pose("table", table_pose)
poses = cps_to_pose(cps, indices)
for i in range(len(poses)):
    b.show_trimesh(f"{i}", b.RENDERER.meshes[best_indices[i]])
    b.set_pose(f"{i}", poses[i])
# Out:
# 2.3046875
# 2.2526042
# 2.2916667
# 2.2526042
# 2.3046875
# 2.2526042
# 2.2526042
# 2.2526042
# 2.2526042
# 2.2864585
# 2.2526042
# 2.2890625
# 2.3177085
# 2.2526042
# 2.2526042
# 2.3489585
# 2.2526042
# 2.2526042
# 2.2526042
# 2.2526042
# 2.2526042

# %%
rendered_images = b.RENDERER.render_many(jnp.array([cps]), indices)[...,:3]
# Out:
# ---------------------------------------------------------------------------
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File /opt/conda/envs/bayes3d-3/lib/python3.9/runpy.py:197, in _run_module_as_main()
#     196     sys.argv[0] = mod_spec.origin
# --> 197 return _run_code(code, main_globals, None,
#     198                  "__main__", mod_spec)
#
# File /opt/conda/envs/bayes3d-3/lib/python3.9/runpy.py:87, in _run_code()
#      80 run_globals.update(__name__ = mod_name,
#      81                    __file__ = fname,
#      82                    __cached__ = cached,
#    (...)
#      85                    __package__ = pkg_name,
#      86                    __spec__ = mod_spec)
# ---> 87 exec(code, run_globals)
#      88 return run_globals
#
# File ~/.local/lib/python3.9/site-packages/ipykernel_launcher.py:17
#      15 from ipykernel import kernelapp as app
# ---> 17 app.launch_new_instance()
#
# File ~/.local/lib/python3.9/site-packages/traitlets/config/application.py:1053, in launch_instance()
#    1052 app.initialize(argv)
# -> 1053 app.start()
#
# File ~/.local/lib/python3.9/site-packages/ipykernel/kernelapp.py:736, in start()
#     735 try:
# --> 736     self.io_loop.start()
#     737 except KeyboardInterrupt:
#
# File ~/.local/lib/python3.9/site-packages/tornado/platform/asyncio.py:195, in start()
#     194 def start(self) -> None:
# --> 195     self.asyncio_loop.run_forever()
#
# File /opt/conda/envs/bayes3d-3/lib/python3.9/asyncio/base_events.py:601, in run_forever()
#     600 while True:
# --> 601     self._run_once()
#     602     if self._stopping:
#
# File /opt/conda/envs/bayes3d-3/lib/python3.9/asyncio/base_events.py:1905, in _run_once()
#    1904     else:
# -> 1905         handle._run()
#    1906 handle = None
#
# File /opt/conda/envs/bayes3d-3/lib/python3.9/asyncio/events.py:80, in _run()
#      79 try:
# ---> 80     self._context.run(self._callback, *self._args)
#      81 except (SystemExit, KeyboardInterrupt):
#
# File ~/.local/lib/python3.9/site-packages/ipykernel/kernelbase.py:516, in dispatch_queue()
#     515 try:
# --> 516     await self.process_one()
#     517 except Exception:
#
# File ~/.local/lib/python3.9/site-packages/ipykernel/kernelbase.py:505, in process_one()
#     504         return None
# --> 505 await dispatch(*args)
#
# File ~/.local/lib/python3.9/site-packages/ipykernel/kernelbase.py:412, in dispatch_shell()
#     411     if inspect.isawaitable(result):
# --> 412         await result
#     413 except Exception:
#
# File ~/.local/lib/python3.9/site-packages/ipykernel/kernelbase.py:740, in execute_request()
#     739 if inspect.isawaitable(reply_content):
# --> 740     reply_content = await reply_content
#     742 # Flush output before sending the reply.
#
# File ~/.local/lib/python3.9/site-packages/ipykernel/ipkernel.py:422, in do_execute()
#     421 if with_cell_id:
# --> 422     res = shell.run_cell(
#     423         code,
#     424         store_history=store_history,
#     425         silent=silent,
#     426         cell_id=cell_id,
#     427     )
#     428 else:
#
# File ~/.local/lib/python3.9/site-packages/ipykernel/zmqshell.py:546, in run_cell()
#     545 self._last_traceback = None
# --> 546 return super().run_cell(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3024, in run_cell()
#    3023 try:
# -> 3024     result = self._run_cell(
#    3025         raw_cell, store_history, silent, shell_futures, cell_id
#    3026     )
#    3027 finally:
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3079, in _run_cell()
#    3078 try:
# -> 3079     result = runner(coro)
#    3080 except BaseException as e:
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/async_helpers.py:129, in _pseudo_sync_runner()
#     128 try:
# --> 129     coro.send(None)
#     130 except StopIteration as exc:
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3284, in run_cell_async()
#    3281 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3284 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3285        interactivity=interactivity, compiler=compiler, result=result)
#    3287 self.last_execution_succeeded = not has_raised
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3466, in run_ast_nodes()
#    3465     asy = compare(code)
# -> 3466 if await self.run_code(code, result, async_=asy):
#    3467     return True
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3526, in run_code()
#    3525     else:
# -> 3526         exec(code_obj, self.user_global_ns, self.user_ns)
#    3527 finally:
#    3528     # Reset our crash handler in place
#
# /home/georgematheos/bayes3d/scripts/experiments/tampura/tampura5.ipynb Cell 17 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B34.148.112.108/home/georgematheos/bayes3d/scripts/experiments/tampura/tampura5.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> rendered_images = b.RENDERER.render_many(jnp.array([cps]), indices)[...,:3]
#
# File ~/bayes3d/bayes3d/renderer.py:141, in render_many()
#     129 """Render many scenes in parallel.
#     130
#     131 Args:
#    (...)
#     139                  the final dimension is the segmentation image.
#     140 """
# --> 141 return self.render_many_custom_intrinsics(poses, indices, self.intrinsics)
#
# File ~/bayes3d/bayes3d/renderer.py:125, in render_many_custom_intrinsics()
#     119 proj_matrix = b.camera._open_gl_projection_matrix(
#     120     intrinsics.height, intrinsics.width,
#     121     intrinsics.fx, intrinsics.fy,
#     122     intrinsics.cx, intrinsics.cy,
#     123     intrinsics.near, intrinsics.far
#     124 )
# --> 125 images_jnp = _render_custom_call(self, poses, indices, proj_matrix)[0]
#     126 return _transform_image_zeros_parallel(images_jnp, intrinsics)
#
# File ~/bayes3d/bayes3d/renderer.py:159, in _render_custom_call()
#     157 @functools.partial(jax.jit, static_argnums=(0,))
#     158 def _render_custom_call(r: "Renderer", poses, indices, intrinsics_matrix):
# --> 159     return _build_render_primitive(r).bind(poses, indices, intrinsics_matrix)
#
# JaxStackTraceBeforeTransformation: NotImplementedError: Only 4D inputs supported: got (1, 11, 3)
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# NotImplementedError                       Traceback (most recent call last)
# /home/georgematheos/bayes3d/scripts/experiments/tampura/tampura5.ipynb Cell 17 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B34.148.112.108/home/georgematheos/bayes3d/scripts/experiments/tampura/tampura5.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> rendered_images = b.RENDERER.render_many(jnp.array([cps]), indices)[...,:3]
#
# File ~/bayes3d/bayes3d/renderer.py:141, in Renderer.render_many(self, poses, indices)
#     128 def render_many(self, poses, indices):
#     129     """Render many scenes in parallel.
#     130
#     131     Args:
#    (...)
#     139                      the final dimension is the segmentation image.
#     140     """
# --> 141     return self.render_many_custom_intrinsics(poses, indices, self.intrinsics)
#
# File ~/bayes3d/bayes3d/renderer.py:125, in Renderer.render_many_custom_intrinsics(self, poses, indices, intrinsics)
#     118 def render_many_custom_intrinsics(self, poses, indices, intrinsics):
#     119     proj_matrix = b.camera._open_gl_projection_matrix(
#     120         intrinsics.height, intrinsics.width,
#     121         intrinsics.fx, intrinsics.fy,
#     122         intrinsics.cx, intrinsics.cy,
#     123         intrinsics.near, intrinsics.far
#     124     )
# --> 125     images_jnp = _render_custom_call(self, poses, indices, proj_matrix)[0]
#     126     return _transform_image_zeros_parallel(images_jnp, intrinsics)
#
#     [... skipping hidden 17 frame]
#
# File ~/bayes3d/bayes3d/renderer.py:181, in _build_render_primitive.<locals>._render_lowering(ctx, poses, indices, intrinsics_matrix)
#     179 poses_aval, indices_aval, intrinsics_matrix_aval = ctx.avals_in
#     180 if poses_aval.ndim != 4:
# --> 181     raise NotImplementedError(f"Only 4D inputs supported: got {poses_aval.shape}")
#     182 if indices_aval.ndim != 1:
#     183     raise NotImplementedError(f"Only 1D inputs supported: got {indices_aval.shape}")
#
# NotImplementedError: Only 4D inputs supported: got (1, 11, 3)

# %%
#####################################
# Below this point is scratch work!
#####################################

# %%
jnp.any(jnp.isnan(obs_img3))
# Out:
# Array(False, dtype=bool)

# %%
cps = jnp.zeros((0,3))
indices = jnp.array([], dtype=jnp.int32)
obs_img = obs_img3

best_score = 0.0
best_index = -1
best_cps = None
best_indices = None
key = jax.random.split(key,2)[0]
low, high = jnp.array([-0.4, -0.4, -jnp.pi]), jnp.array([0.4, 0.4, jnp.pi])

# for _ in range(10):
# for next_index in [18]: # range(len(b.RENDERER.model_box_dims)):
next_index = 18
potential_indices = jnp.concatenate([indices, jnp.array([next_index])])
potential_cps = jnp.concatenate([cps, jax.random.uniform(key, shape=(1,3,),minval=low, maxval=high)])
# potential_cps = jnp.concatenate([cps, jnp.array([[0.0, 0.0, 0.0]])])

key, potential_cps, potential_indices, number, contact_param_gridding_schedule, obs_img = key, potential_cps, potential_indices, len(potential_indices) - 1, contact_param_gridding_schedule, obs_img

cp_grid = contact_param_gridding_schedule[0]
key, cps, indices, number, grid, obs_img = key, potential_cps, potential_indices, number, cp_grid, obs_img

# this was done to clear memory - uncomment to fix
cps_expanded = None # jnp.repeat(cps[None,...], grid.shape[0], axis=0)
cps_expanded = None #  cps_expanded.at[:,number,:].set(cps_expanded[:,number,:] + grid)
cp_poses = None # cps_to_pose_parallel(cps_expanded, indices)
rendered_images = None # b.RENDERER.render_many(cp_poses, indices)[...,:3]
scores = None # score_vmap(rendered_images, obs_img)

# %%
scores = None
log_norm_scores = None
norm_scores = None

# %%
norm_log_scores = scores - jax.scipy.special.logsumexp(scores)
norm_scores = jnp.exp(norm_log_scores)
key = jax.random.split(key,2)[0]
idx = jax.random.categorical(key, scores / scores.sum())
# cps_to_pose(jnp.array([cps_expanded[idx]]), jnp.array([18]))
idx2 = jnp.argmax(scores)
poses = cps_to_pose(cps_expanded[idx2], jnp.array([18]))

b.clear()
b.show_cloud("obs", obs_img.reshape(-1,3))
b.show_trimesh(f"18", b.RENDERER.meshes[18])
b.set_pose(f"18", poses[0])

# %%
# get 100 samples from the categorical
samples = []
for _ in range(100):
    key = jax.random.split(key,2)[0]
    idx = jax.random.categorical(key, scores / scores.sum())
    samples.append(idx)
# count num unique samples:
np.unique(np.array(samples)).shape
# Out:
# (100,)

# %%
ns = scores / scores.sum()
plt.plot(ns)
plt.show()
ns[ns > 0.01].sum()
# Out:
# Array(0.6960785, dtype=float32)

# %%
    
    
    
    
    
    
    
    
    
    
    
    potential_cps, score, score2 = c2f_jit(key, potential_cps, potential_indices, len(potential_indices) - 1, contact_param_gridding_schedule, obs_img)
    print(score, score2)
    if score > best_score:
        best_index = next_index
        best_score = score
        best_cps = potential_cps
        best_indices = potential_indices
cps = best_cps
indices = best_indices

b.clear()
b.show_cloud("obs", obs_img.reshape(-1,3))
b.show_pose("table", table_pose)
# poses = cps_to_pose(cps, indices)
# for i in range(len(poses)):
#     b.show_trimesh(f"{i}", b.RENDERER.meshes[best_indices[i]])
#     b.set_pose(f"{i}", poses[i])
# Out:
# Array(0, dtype=int32)
